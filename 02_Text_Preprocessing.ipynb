# %%
import pandas as pd
import numpy as np
import re
import string
import nltk

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
fake_df = pd.read_csv("Fake.csv")
true_df = pd.read_csv("True.csv")

fake_df["label"] = 0
true_df["label"] = 1

news_df = pd.concat([fake_df, true_df], ignore_index=True)

news_df = news_df.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
# !ls /content/drive/MyDrive
# Out:
# 'Colab Notebooks'
# 'Personal Brand Digital Age - Final (1).gslides'
# 'Personal Brand Digital Age - Final (2).gslides'
# 'Personal Brand Digital Age - Final (3).gslides'
# 'Personal Brand Digital Age - Final Deck (1).gslides'
# 'Personal Brand Digital Age - Final Deck (2).gslides'
# 'Personal Brand Digital Age - Final Deck.gslides'
# 'Personal Brand Digital Age - Final.gslides'
# 'Personal Brand Digital Age Slides.gslides'
#  preprocessed_news.csv
# 'SPM ECO System Proposal Defense (1).gslides'
# 'SPM ECO System Proposal Defense (2).gslides'
# 'SPM ECO System Proposal Defense.gslides'
# 'Untitled project (1).gscript'
# 'Untitled project (2).gscript'
# 'Untitled project (3).gscript'
# 'Untitled project (4).gscript'
# 'Untitled project (5).gscript'
# 'Untitled project.gscript'

# %%
news_df["content"] = news_df["title"] + " " + news_df["text"]

# %%
news_df[["content", "label"]].head()
# Out:
#                                              content  label
# 0  Ben Stein Calls Out 9th Circuit Court: Committ...      0
# 1  Trump drops Steve Bannon from National Securit...      1
# 2  Puerto Rico expects U.S. to lift Jones Act shi...      1
# 3   OOPS: Trump Just Accidentally Confirmed He Le...      0
# 4  Donald Trump heads for Scotland to reopen a go...      1

# %%
news_df["content"] = news_df["title"] + " " + news_df["text"]

news_df[["content", "label"]].head()
# Out:
#                                              content  label
# 0  Ben Stein Calls Out 9th Circuit Court: Committ...      0
# 1  Trump drops Steve Bannon from National Securit...      1
# 2  Puerto Rico expects U.S. to lift Jones Act shi...      1
# 3   OOPS: Trump Just Accidentally Confirmed He Le...      0
# 4  Donald Trump heads for Scotland to reopen a go...      1

# %%
news_df["content"] = news_df["content"].str.lower()

# %%
news_df[["content"]].head()
# Out:
#                                              content
# 0  ben stein calls out 9th circuit court: committ...
# 1  trump drops steve bannon from national securit...
# 2  puerto rico expects u.s. to lift jones act shi...
# 3   oops: trump just accidentally confirmed he le...
# 4  donald trump heads for scotland to reopen a go...

# %%
news_df["content"] = news_df["content"].str.lower()

news_df[["content"]].head()
# Out:
#                                              content
# 0  ben stein calls out 9th circuit court: committ...
# 1  trump drops steve bannon from national securit...
# 2  puerto rico expects u.s. to lift jones act shi...
# 3   oops: trump just accidentally confirmed he le...
# 4  donald trump heads for scotland to reopen a go...

# %%
def remove_urls(text):
    text = re.sub(r'http\S+', '', text)
    text = re.sub(r'www\S+', '', text)
    return text

# %%
news_df["content"] = news_df["content"].apply(remove_urls)

# %%
news_df[["content"]].head()
# Out:
#                                              content
# 0  ben stein calls out 9th circuit court: committ...
# 1  trump drops steve bannon from national securit...
# 2  puerto rico expects u.s. to lift jones act shi...
# 3   oops: trump just accidentally confirmed he le...
# 4  donald trump heads for scotland to reopen a go...

# %%
def remove_urls(text):
    text = re.sub(r'http\S+', '', text)
    text = re.sub(r'www\S+', '', text)
    return text

# %%
news_df["content"] = news_df["content"].apply(remove_urls)

# %%
news_df[["content"]].head()
# Out:
#                                              content
# 0  ben stein calls out 9th circuit court: committ...
# 1  trump drops steve bannon from national securit...
# 2  puerto rico expects u.s. to lift jones act shi...
# 3   oops: trump just accidentally confirmed he le...
# 4  donald trump heads for scotland to reopen a go...

# %%
def remove_html(text):
    return re.sub(r'<.*?>', '', text)

# %%
news_df["content"] = news_df["content"].apply(remove_html)

# %%
news_df[["content"]].head()
# Out:
#                                              content
# 0  ben stein calls out 9th circuit court: committ...
# 1  trump drops steve bannon from national securit...
# 2  puerto rico expects u.s. to lift jones act shi...
# 3   oops: trump just accidentally confirmed he le...
# 4  donald trump heads for scotland to reopen a go...

# %%
def remove_punctuation(text):
    return text.translate(str.maketrans('', '', string.punctuation))

# %%
news_df["content"] = news_df["content"].apply(remove_punctuation)

# %%
news_df[["content"]].head()
# Out:
#                                              content
# 0  ben stein calls out 9th circuit court committe...
# 1  trump drops steve bannon from national securit...
# 2  puerto rico expects us to lift jones act shipp...
# 3   oops trump just accidentally confirmed he lea...
# 4  donald trump heads for scotland to reopen a go...

# %%
def remove_numbers(text):
    return re.sub(r'\d+', '', text)

# %%
news_df["content"] = news_df["content"].apply(remove_numbers)

# %%
news_df[["content"]].head()
# Out:
#                                              content
# 0  ben stein calls out th circuit court committed...
# 1  trump drops steve bannon from national securit...
# 2  puerto rico expects us to lift jones act shipp...
# 3   oops trump just accidentally confirmed he lea...
# 4  donald trump heads for scotland to reopen a go...

# %%
news_df[["content"]].head()
# Out:
#                                              content
# 0  ben stein calls out th circuit court committed...
# 1  trump drops steve bannon from national securit...
# 2  puerto rico expects us to lift jones act shipp...
# 3   oops trump just accidentally confirmed he lea...
# 4  donald trump heads for scotland to reopen a go...

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize

news_df["tokens"] = news_df["content"].apply(word_tokenize)

# %%
import nltk

nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize

news_df["tokens"] = news_df["content"].apply(word_tokenize)

news_df[["tokens"]].head()
# Out:
#                                               tokens
# 0  [ben, stein, calls, out, th, circuit, court, c...
# 1  [trump, drops, steve, bannon, from, national, ...
# 2  [puerto, rico, expects, us, to, lift, jones, a...
# 3  [oops, trump, just, accidentally, confirmed, h...
# 4  [donald, trump, heads, for, scotland, to, reop...

# %%
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))

# %%
def remove_stopwords(tokens):
    return [word for word in tokens if word not in stop_words]

# %%
news_df["tokens"] = news_df["tokens"].apply(remove_stopwords)

# %%
news_df[["tokens"]].head()
# Out:
#                                               tokens
# 0  [ben, stein, calls, th, circuit, court, commit...
# 1  [trump, drops, steve, bannon, national, securi...
# 2  [puerto, rico, expects, us, lift, jones, act, ...
# 3  [oops, trump, accidentally, confirmed, leaked,...
# 4  [donald, trump, heads, scotland, reopen, golf,...

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

# %%
def lemmatize_tokens(tokens):
    return [lemmatizer.lemmatize(word) for word in tokens]

# %%
news_df["tokens"] = news_df["tokens"].apply(lemmatize_tokens)

# %%
news_df[["tokens"]].head()
# Out:
#                                               tokens
# 0  [ben, stein, call, th, circuit, court, committ...
# 1  [trump, drop, steve, bannon, national, securit...
# 2  [puerto, rico, expects, u, lift, jones, act, s...
# 3  [oops, trump, accidentally, confirmed, leaked,...
# 4  [donald, trump, head, scotland, reopen, golf, ...

# %%
news_df["clean_text"] = news_df["tokens"].apply(lambda x: " ".join(x))

# %%
news_df[["clean_text", "label"]].head()
# Out:
#                                           clean_text  label
# 0  ben stein call th circuit court committed ‘ co...      0
# 1  trump drop steve bannon national security coun...      1
# 2  puerto rico expects u lift jones act shipping ...      1
# 3  oops trump accidentally confirmed leaked israe...      0
# 4  donald trump head scotland reopen golf resort ...      1

# %%
news_df.to_csv("preprocessed_news.csv", index=False)

print("Preprocessed dataset saved successfully!")
# Out:
# Preprocessed dataset saved successfully!

# %%
import os

os.listdir()
# Out:
# ['.config',
#  'Fake.csv',
#  'True.csv',
#  'preprocessed_news.csv',
#  'drive',
#  'sample_data']

# %%
from google.colab import drive
drive.mount('/content/drive')

news_df.to_csv('/content/drive/MyDrive/preprocessed_news.csv', index=False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
