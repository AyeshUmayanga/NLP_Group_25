# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
fake_df = pd.read_csv("Fake.csv")
true_df = pd.read_csv("True.csv")

# %%
fake_df.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true_df.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
import pandas as pd

fake_df = pd.read_csv("Fake.csv")
true_df = pd.read_csv("True.csv")

fake_df.head()
true_df.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
print("Fake News Dataset Shape:", fake_df.shape)
print("True News Dataset Shape:", true_df.shape)
# Out:
# Fake News Dataset Shape: (23481, 4)
# True News Dataset Shape: (21417, 4)

# %%
print("Fake Dataset Columns:")
print(fake_df.columns)

print("\nTrue Dataset Columns:")
print(true_df.columns)
# Out:
# Fake Dataset Columns:
# Index(['title', 'text', 'subject', 'date'], dtype='object')
#
# True Dataset Columns:
# Index(['title', 'text', 'subject', 'date'], dtype='object')

# %%
fake_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23481 entries, 0 to 23480
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    23481 non-null  object
#  1   text     23481 non-null  object
#  2   subject  23481 non-null  object
#  3   date     23481 non-null  object
# dtypes: object(4)
# memory usage: 733.9+ KB

# %%
true_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21417 entries, 0 to 21416
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    21417 non-null  object
#  1   text     21417 non-null  object
#  2   subject  21417 non-null  object
#  3   date     21417 non-null  object
# dtypes: object(4)
# memory usage: 669.4+ KB

# %%
fake_df["label"] = 0
true_df["label"] = 1

# %%
fake_df.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
true_df.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  label
# 0  December 31, 2017       1
# 1  December 29, 2017       1
# 2  December 31, 2017       1
# 3  December 30, 2017       1
# 4  December 29, 2017       1

# %%
news_df = pd.concat([fake_df, true_df], ignore_index=True)

# %%
news_df.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
news_df.shape
# Out:
# (44898, 5)

# %%
news_df = pd.concat([fake_df, true_df], ignore_index=True)

news_df.head()

news_df.shape
# Out:
# (44898, 5)

# %%
news_df = news_df.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
news_df.head(10)
# Out:
#                                                title  \
# 0  Ben Stein Calls Out 9th Circuit Court: Committ...
# 1  Trump drops Steve Bannon from National Securit...
# 2  Puerto Rico expects U.S. to lift Jones Act shi...
# 3   OOPS: Trump Just Accidentally Confirmed He Le...
# 4  Donald Trump heads for Scotland to reopen a go...
# 5   Paul Ryan Responds To Dem’s Sit-In On Gun Con...
# 6  AWESOME! DIAMOND AND SILK Rip Into The Press: ...
# 7  STAND UP AND CHEER! UKIP Party Leader SLAMS Ge...
# 8  North Korea shows no sign it is serious about ...
# 9  Trump signals willingness to raise U.S. minimu...
#
#                                                 text          subject  \
# 0  21st Century Wire says Ben Stein, reputable pr...          US_News
# 1  WASHINGTON (Reuters) - U.S. President Donald T...     politicsNews
# 2  (Reuters) - Puerto Rico Governor Ricardo Rosse...     politicsNews
# 3  On Monday, Donald Trump once again embarrassed...             News
# 4  GLASGOW, Scotland (Reuters) - Most U.S. presid...     politicsNews
# 5  On Wednesday, Democrats took a powerful stance...             News
# 6  President Trump s rally in FL on Saturday was ...  Government News
# 7  He s been Europe s version of the outspoken Te...        left-news
# 8  WASHINGTON (Reuters) - The State Department sa...        worldnews
# 9   (This version of the story corrects the figur...     politicsNews
#
#                   date  label
# 0    February 13, 2017      0
# 1       April 5, 2017       1
# 2  September 27, 2017       1
# 3         May 22, 2017      0
# 4       June 24, 2016       1
# 5        June 22, 2016      0
# 6         Feb 19, 2017      0
# 7          Mar 8, 2016      0
# 8   December 13, 2017       1
# 9         May 4, 2016       1

# %%
news_df = news_df.sample(frac=1, random_state=42).reset_index(drop=True)

news_df.head(10)
# Out:
#                                                title  \
# 0   It’s Really Happening: Trump Adviser Lays Out...
# 1  Republican attempt to deflect Trump-Russia pro...
# 2  Trump says churches should get FEMA funds for ...
# 3   Trump Loves To Say The New York Times Is ‘Fai...
# 4  House Speaker Ryan briefed Trump on healthcare...
# 5  Government leakers are 'enemies to our state,'...
# 6  DELUSIONAL OBAMA BLAMES “Fake News” For Hillar...
# 7  WATCH: SENATOR RAND PAUL Calls For Investigati...
# 8  U.S. top court poised to overturn Virginia ex-...
# 9   Company Drops Gloria Steinem After Bullied By...
#
#                                                 text          subject  \
# 0  Well, that didn t take long. In the short time...             News
# 1  (Reuters) - Republican lawmaker Devin Nunes’ i...     politicsNews
# 2  WASHINGTON (Reuters) - President Donald Trump ...     politicsNews
# 3  Print journalism and longstanding papers have ...             News
# 4  WASHINGTON (Reuters) - President Donald Trump ...     politicsNews
# 5  WASHINGTON (Reuters) - Individuals who steal c...     politicsNews
# 6                                                     Government News
# 7  Senator Rand Paul appeared on Bill Hemmer s Fo...         politics
# 8  WASHINGTON (Reuters) - The U.S. Supreme Court ...     politicsNews
# 9  You d think that in the year 2016, companies w...             News
#
#                   date  label
# 0    November 16, 2016      0
# 1  September 11, 2017       1
# 2   September 9, 2017       1
# 3       August 7, 2017      0
# 4      March 24, 2017       1
# 5      March 15, 2017       1
# 6         Nov 20, 2016      0
# 7         Dec 21, 2017      0
# 8      April 27, 2016       1
# 9    February 25, 2016      0

# %%
news_df["label"].value_counts()
# Out:
# label
# 0    23481
# 1    21417
# Name: count, dtype: int64

# %%
news_df["label"].value_counts(normalize=True) * 100
# Out:
# label
# 0    52.298543
# 1    47.701457
# Name: proportion, dtype: float64

# %%
news_df.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# label      0
# dtype: int64

# %%
# Count classes
news_df["label"].value_counts()

# Class percentages
news_df["label"].value_counts(normalize=True) * 100

# Missing values
news_df.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# label      0
# dtype: int64

# %%
# Count of each class
print("Class Counts:")
print(news_df["label"].value_counts())

print("\n----------------------\n")

# Percentage of each class
print("Class Percentages:")
print(news_df["label"].value_counts(normalize=True) * 100)

print("\n----------------------\n")

# Missing values
print("Missing Values:")
print(news_df.isnull().sum())
# Out:
# Class Counts:
# label
# 0    23481
# 1    21417
# Name: count, dtype: int64
#
# ----------------------
#
# Class Percentages:
# label
# 0    52.298543
# 1    47.701457
# Name: proportion, dtype: float64
#
# ----------------------
#
# Missing Values:
# title      0
# text       0
# subject    0
# date       0
# label      0
# dtype: int64
